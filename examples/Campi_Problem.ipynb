# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from zonolayer import Zonolayer

# %% [markdown]
# This notebook uses a similar architecture used in the following [paper](https://www.sciencedirect.com/science/article/pii/S0893608019301935?via%3Dihub) to solve a simple problem proposed by [Campi et al. (2015)](https://ieeexplore.ieee.org/abstract/document/7402845), using our zonolayer as opposed to the IPM.

# %%
class CentreNet(nn.Module):
    def __init__(self, input_dim=1, hidden_dim=128, latent_dim=10):
        super().__init__()
        self.feature_net = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, latent_dim),
        )
        self.output_layer = nn.Linear(latent_dim, 1)

    def forward(self, x, return_latent=False):
        latent = self.feature_net(x)
        y = self.output_layer(latent)
        if return_latent:
            return y, latent
        return y

# 2. Generate synthetic data


def nonlinear_data(n):
    n_samples = n
    x = np.random.rand(n_samples)
    w = np.random.normal(0, 0.025, n_samples)
    y = 0.3 * (15 * x * np.exp(-3 * x) + w * x)
    y_radius = (1/160) * (np.abs(x - 0.5) + 0.1)
    y_lower = y - y_radius
    y_upper = y + y_radius

    x_grid = np.linspace(0, 10, n_samples)

    return n_samples, x, y, y_lower, y_upper, x_grid


n, x, y, y_lower, y_upper, x_grid = nonlinear_data(1250)

# Tensor conversion for PyTorch
y_lb_t = torch.tensor(y_lower, dtype=torch.float32).unsqueeze(1)
y_ub_t = torch.tensor(y_upper, dtype=torch.float32).unsqueeze(1)
x_t = torch.tensor(x, dtype=torch.float32).unsqueeze(1)

# 3. Train the centre network on the midpoints of the intervals to fit a regression line

def train_centre(x_t, y_lb_t, y_ub_t, epochs=3000, lr=1e-3, batch_size=64, print_every=20, decay=0.96):
    y_mid = 0.5 * (y_lb_t + y_ub_t)  # midpoints

    centre_net = CentreNet(input_dim=x_t.shape[1])
    optimizer = torch.optim.Adam(centre_net.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=decay)  # decay factor per epoch
    criterion = nn.MSELoss()

    n_samples = x_t.shape[0]

    for epoch in range(epochs):
        perm = torch.randperm(n_samples)
        epoch_loss = 0.0
        for i in range(0, n_samples, batch_size):
            idx = perm[i:i+batch_size]
            xb = x_t[idx]
            yb = y_mid[idx]

            pred = centre_net(xb)
            loss = criterion(pred, yb)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            epoch_loss += loss.item() * len(xb)

        scheduler.step()  # update learning rate after each epoch

        if (epoch + 1) % print_every == 0:
            current_lr = optimizer.param_groups[0]['lr']
            print(f"Epoch {epoch+1}: MSE = {epoch_loss / n_samples:.6f}, LR = {current_lr:.6e}")

    return centre_net



centre_net = train_centre(x_t, y_lb_t, y_ub_t)
# Out:
# Epoch 20: MSE = 0.000241, LR = 1.000000e-03
# Epoch 40: MSE = 0.000042, LR = 1.000000e-03
# Epoch 60: MSE = 0.000030, LR = 1.000000e-03
# Epoch 80: MSE = 0.000053, LR = 1.000000e-03
# Epoch 100: MSE = 0.000033, LR = 9.600000e-04
# Epoch 120: MSE = 0.000045, LR = 9.600000e-04
# Epoch 140: MSE = 0.000045, LR = 9.600000e-04
# Epoch 160: MSE = 0.000033, LR = 9.600000e-04
# Epoch 180: MSE = 0.000025, LR = 9.600000e-04
# Epoch 200: MSE = 0.000032, LR = 9.216000e-04
# Epoch 220: MSE = 0.000028, LR = 9.216000e-04
# Epoch 240: MSE = 0.000030, LR = 9.216000e-04
# Epoch 260: MSE = 0.000037, LR = 9.216000e-04
# Epoch 280: MSE = 0.000024, LR = 9.216000e-04
# Epoch 300: MSE = 0.000023, LR = 8.847360e-04
# Epoch 320: MSE = 0.000024, LR = 8.847360e-04
# Epoch 340: MSE = 0.000028, LR = 8.847360e-04
# Epoch 360: MSE = 0.000044, LR = 8.847360e-04
# Epoch 380: MSE = 0.000038, LR = 8.847360e-04
# Epoch 400: MSE = 0.000033, LR = 8.493466e-04
# Epoch 420: MSE = 0.000025, LR = 8.493466e-04
# Epoch 440: MSE = 0.000024, LR = 8.493466e-04
# Epoch 460: MSE = 0.000024, LR = 8.493466e-04
# Epoch 480: MSE = 0.000032, LR = 8.493466e-04
# Epoch 500: MSE = 0.000035, LR = 8.153727e-04
# Epoch 520: MSE = 0.000033, LR = 8.153727e-04
# Epoch 540: MSE = 0.000023, LR = 8.153727e-04
# Epoch 560: MSE = 0.000020, LR = 8.153727e-04
# Epoch 580: MSE = 0.000026, LR = 8.153727e-04
# Epoch 600: MSE = 0.000023, LR = 7.827578e-04
# Epoch 620: MSE = 0.000022, LR = 7.827578e-04
# Epoch 640: MSE = 0.000025, LR = 7.827578e-04
# Epoch 660: MSE = 0.000023, LR = 7.827578e-04
# Epoch 680: MSE = 0.000023, LR = 7.827578e-04
# Epoch 700: MSE = 0.000022, LR = 7.514475e-04
# Epoch 720: MSE = 0.000021, LR = 7.514475e-04
# Epoch 740: MSE = 0.000023, LR = 7.514475e-04
# Epoch 760: MSE = 0.000024, LR = 7.514475e-04
# Epoch 780: MSE = 0.000020, LR = 7.514475e-04
# Epoch 800: MSE = 0.000026, LR = 7.213896e-04
# Epoch 820: MSE = 0.000022, LR = 7.213896e-04
# Epoch 840: MSE = 0.000023, LR = 7.213896e-04
# Epoch 860: MSE = 0.000021, LR = 7.213896e-04
# Epoch 880: MSE = 0.000033, LR = 7.213896e-04
# Epoch 900: MSE = 0.000023, LR = 6.925340e-04
# Epoch 920: MSE = 0.000022, LR = 6.925340e-04
# Epoch 940: MSE = 0.000024, LR = 6.925340e-04
# Epoch 960: MSE = 0.000023, LR = 6.925340e-04
# Epoch 980: MSE = 0.000023, LR = 6.925340e-04
# Epoch 1000: MSE = 0.000021, LR = 6.648326e-04
# Epoch 1020: MSE = 0.000024, LR = 6.648326e-04
# Epoch 1040: MSE = 0.000023, LR = 6.648326e-04
# Epoch 1060: MSE = 0.000022, LR = 6.648326e-04
# Epoch 1080: MSE = 0.000020, LR = 6.648326e-04
# Epoch 1100: MSE = 0.000026, LR = 6.382393e-04
# Epoch 1120: MSE = 0.000026, LR = 6.382393e-04
# Epoch 1140: MSE = 0.000023, LR = 6.382393e-04
# Epoch 1160: MSE = 0.000026, LR = 6.382393e-04
# Epoch 1180: MSE = 0.000022, LR = 6.382393e-04
# Epoch 1200: MSE = 0.000024, LR = 6.127098e-04
# Epoch 1220: MSE = 0.000025, LR = 6.127098e-04
# Epoch 1240: MSE = 0.000022, LR = 6.127098e-04
# Epoch 1260: MSE = 0.000021, LR = 6.127098e-04
# Epoch 1280: MSE = 0.000024, LR = 6.127098e-04
# Epoch 1300: MSE = 0.000022, LR = 5.882014e-04
# Epoch 1320: MSE = 0.000023, LR = 5.882014e-04
# Epoch 1340: MSE = 0.000020, LR = 5.882014e-04
# Epoch 1360: MSE = 0.000021, LR = 5.882014e-04
# Epoch 1380: MSE = 0.000026, LR = 5.882014e-04
# Epoch 1400: MSE = 0.000020, LR = 5.646733e-04
# Epoch 1420: MSE = 0.000020, LR = 5.646733e-04
# Epoch 1440: MSE = 0.000023, LR = 5.646733e-04
# Epoch 1460: MSE = 0.000022, LR = 5.646733e-04
# Epoch 1480: MSE = 0.000022, LR = 5.646733e-04
# Epoch 1500: MSE = 0.000023, LR = 5.420864e-04
# Epoch 1520: MSE = 0.000022, LR = 5.420864e-04
# Epoch 1540: MSE = 0.000020, LR = 5.420864e-04
# Epoch 1560: MSE = 0.000022, LR = 5.420864e-04
# Epoch 1580: MSE = 0.000020, LR = 5.420864e-04
# Epoch 1600: MSE = 0.000023, LR = 5.204029e-04
# Epoch 1620: MSE = 0.000022, LR = 5.204029e-04
# Epoch 1640: MSE = 0.000021, LR = 5.204029e-04
# Epoch 1660: MSE = 0.000023, LR = 5.204029e-04
# Epoch 1680: MSE = 0.000024, LR = 5.204029e-04
# Epoch 1700: MSE = 0.000021, LR = 4.995868e-04
# Epoch 1720: MSE = 0.000022, LR = 4.995868e-04
# Epoch 1740: MSE = 0.000022, LR = 4.995868e-04
# Epoch 1760: MSE = 0.000022, LR = 4.995868e-04
# Epoch 1780: MSE = 0.000021, LR = 4.995868e-04
# Epoch 1800: MSE = 0.000020, LR = 4.796033e-04
# Epoch 1820: MSE = 0.000021, LR = 4.796033e-04
# Epoch 1840: MSE = 0.000022, LR = 4.796033e-04
# Epoch 1860: MSE = 0.000021, LR = 4.796033e-04
# Epoch 1880: MSE = 0.000025, LR = 4.796033e-04
# Epoch 1900: MSE = 0.000020, LR = 4.604192e-04
# Epoch 1920: MSE = 0.000022, LR = 4.604192e-04
# Epoch 1940: MSE = 0.000021, LR = 4.604192e-04
# Epoch 1960: MSE = 0.000021, LR = 4.604192e-04
# Epoch 1980: MSE = 0.000023, LR = 4.604192e-04
# Epoch 2000: MSE = 0.000022, LR = 4.420024e-04
# Epoch 2020: MSE = 0.000020, LR = 4.420024e-04
# Epoch 2040: MSE = 0.000020, LR = 4.420024e-04
# Epoch 2060: MSE = 0.000021, LR = 4.420024e-04
# Epoch 2080: MSE = 0.000021, LR = 4.420024e-04
# Epoch 2100: MSE = 0.000021, LR = 4.243223e-04
# Epoch 2120: MSE = 0.000021, LR = 4.243223e-04
# Epoch 2140: MSE = 0.000021, LR = 4.243223e-04
# Epoch 2160: MSE = 0.000020, LR = 4.243223e-04
# Epoch 2180: MSE = 0.000021, LR = 4.243223e-04
# Epoch 2200: MSE = 0.000020, LR = 4.073494e-04
# Epoch 2220: MSE = 0.000021, LR = 4.073494e-04
# Epoch 2240: MSE = 0.000019, LR = 4.073494e-04
# Epoch 2260: MSE = 0.000019, LR = 4.073494e-04
# Epoch 2280: MSE = 0.000022, LR = 4.073494e-04
# Epoch 2300: MSE = 0.000021, LR = 3.910555e-04
# Epoch 2320: MSE = 0.000020, LR = 3.910555e-04
# Epoch 2340: MSE = 0.000021, LR = 3.910555e-04
# Epoch 2360: MSE = 0.000021, LR = 3.910555e-04
# Epoch 2380: MSE = 0.000021, LR = 3.910555e-04
# Epoch 2400: MSE = 0.000022, LR = 3.754132e-04
# Epoch 2420: MSE = 0.000020, LR = 3.754132e-04
# Epoch 2440: MSE = 0.000022, LR = 3.754132e-04
# Epoch 2460: MSE = 0.000020, LR = 3.754132e-04
# Epoch 2480: MSE = 0.000021, LR = 3.754132e-04
# Epoch 2500: MSE = 0.000020, LR = 3.603967e-04
# Epoch 2520: MSE = 0.000020, LR = 3.603967e-04
# Epoch 2540: MSE = 0.000023, LR = 3.603967e-04
# Epoch 2560: MSE = 0.000021, LR = 3.603967e-04
# Epoch 2580: MSE = 0.000020, LR = 3.603967e-04
# Epoch 2600: MSE = 0.000021, LR = 3.459808e-04
# Epoch 2620: MSE = 0.000020, LR = 3.459808e-04
# Epoch 2640: MSE = 0.000021, LR = 3.459808e-04
# Epoch 2660: MSE = 0.000023, LR = 3.459808e-04
# Epoch 2680: MSE = 0.000019, LR = 3.459808e-04
# Epoch 2700: MSE = 0.000020, LR = 3.321416e-04
# Epoch 2720: MSE = 0.000020, LR = 3.321416e-04
# Epoch 2740: MSE = 0.000020, LR = 3.321416e-04
# Epoch 2760: MSE = 0.000020, LR = 3.321416e-04
# Epoch 2780: MSE = 0.000020, LR = 3.321416e-04
# Epoch 2800: MSE = 0.000019, LR = 3.188559e-04
# Epoch 2820: MSE = 0.000019, LR = 3.188559e-04
# Epoch 2840: MSE = 0.000021, LR = 3.188559e-04
# Epoch 2860: MSE = 0.000021, LR = 3.188559e-04
# Epoch 2880: MSE = 0.000020, LR = 3.188559e-04
# Epoch 2900: MSE = 0.000020, LR = 3.061017e-04
# Epoch 2920: MSE = 0.000019, LR = 3.061017e-04
# Epoch 2940: MSE = 0.000021, LR = 3.061017e-04
# Epoch 2960: MSE = 0.000020, LR = 3.061017e-04
# Epoch 2980: MSE = 0.000020, LR = 3.061017e-04
# Epoch 3000: MSE = 0.000020, LR = 2.938576e-04

# %%
# Test points
test_set = torch.linspace(x_t.min(), x_t.max(), n).unsqueeze(1)

zl = Zonolayer(centre_net, lambda_reg=1e-4, alpha=0.05)
results, ipm_lower, ipm_upper = zl.compute(x_t, test_set, y_lower, y_upper, ipm=True)

# Unpack results
y_lower_pred = results["y_lower_pred"]
y_upper_pred = results["y_upper_pred"]
pi_lower = results["pi_lower"]
pi_upper = results["pi_upper"]
centre_pred = results["pred_centre"]


x_plot = np.linspace(x_t.min(), x_t.max(), n)

plt.figure(figsize=(8, 5))

x_sorted, idx = torch.sort(x_t, dim=0)
y_lb_sorted = y_lb_t[idx]
y_ub_sorted = y_ub_t[idx]

plt.vlines(x_sorted.numpy().flatten(),
           y_lb_sorted.numpy().flatten(),
           y_ub_sorted.numpy().flatten(),
           color='black', alpha=.5, linewidth=0.5,
           label='Data intervals')

# Plot NN prediction
#plt.plot(x_plot.numpy(), centre_pred, color='red', lw=1.5, label='NN prediction', zorder=5)

#plt.plot(x_plot.numpy(), y_lower_pred, 'g', lw=1.5, label='Zonotopic bounds', alpha=0.8)
#plt.plot(x_plot.numpy(), y_upper_pred, 'g', lw=1.5, label='__nolegend__', alpha=0.8)

plt.plot(x_plot.numpy(), ipm_lower, 'g--', lw=1.5,
          label='IPM', alpha=0.8)
plt.plot(x_plot.numpy(), ipm_upper, 'g--', lw=1.5,
          label='__nolegend__', alpha=0.8)

plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.savefig(""
"IPMCampi.pdf", bbox_inches="tight")
plt.show()
# Out:
#      pcost       dcost       gap    pres   dres   k/t
#  0: -1.1102e-16  5.6843e-14  5e+03  2e+00  3e+03  1e+00
#  1:  1.9066e-01  6.9609e-02  1e+02  3e-01  3e+02  2e-03
#  2:  2.6971e-02  2.7958e-02  9e-01  2e-02  2e+01  9e-03
#  3:  3.0114e-02  3.1963e-02  1e+00  2e-02  2e+01  1e-02
#  4:  3.0919e-02  3.1547e-02  5e-01  1e-02  1e+01  5e-03
#  5:  3.0328e-02  3.0170e-02  3e-01  7e-03  7e+00  3e-03
#  6:  3.1846e-02  3.1141e-02  2e-01  5e-03  5e+00  1e-03
#  7:  3.1625e-02  3.1326e-02  5e-02  1e-03  1e+00  3e-04
#  8:  3.0462e-02  3.0294e-02  2e-02  7e-04  7e-01  1e-04
#  9:  3.0541e-02  3.0371e-02  2e-02  7e-04  7e-01  1e-04
# 10:  3.1168e-02  3.0999e-02  2e-02  5e-04  6e-01  5e-05
# 11:  3.0904e-02  3.0785e-02  1e-02  3e-04  3e-01  2e-06
# 12:  3.0990e-02  3.0949e-02  3e-03  1e-04  1e-01  7e-07
# 13:  3.0987e-02  3.0962e-02  2e-03  6e-05  6e-02  4e-07
# 14:  3.1002e-02  3.0986e-02  1e-03  4e-05  4e-02  3e-07
# 15:  3.1007e-02  3.0999e-02  7e-04  2e-05  2e-02  1e-07
# 16:  3.1025e-02  3.1023e-02  2e-04  7e-06  7e-03  5e-08
# 17:  3.1029e-02  3.1028e-02  1e-04  3e-06  3e-03  2e-08
# 18:  3.1030e-02  3.1029e-02  9e-05  3e-06  3e-03  2e-08
# 19:  3.1031e-02  3.1030e-02  6e-05  2e-06  2e-03  1e-08
# 20:  3.1032e-02  3.1031e-02  4e-05  1e-06  1e-03  8e-09
# 21:  3.1033e-02  3.1033e-02  8e-06  2e-07  2e-04  2e-09
# 22:  3.1033e-02  3.1033e-02  2e-06  4e-08  4e-05  3e-10
# 23:  3.1033e-02  3.1033e-02  1e-06  3e-08  3e-05  2e-10
# 24:  3.1033e-02  3.1032e-02  6e-07  1e-08  1e-05  1e-10
# 25:  3.1033e-02  3.1033e-02  2e-07  5e-09  5e-06  4e-11
# 26:  3.1033e-02  3.1040e-02  1e-07  3e-09  3e-06  2e-11
# Terminated (singular KKT matrix).
